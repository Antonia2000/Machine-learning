# %%
cur_x = 3 
rate = 0.01 
precision = 0.000001 
previous_step_size = 1 
max_iters = 10000 # max iter
i = 0 #iteration counter
df = lambda x: 12 * x -12 
while previous_step_size > precision and i < max_iters:
    prev_x = cur_x 
    cur_x = cur_x - rate * df(prev_x)
    previous_step_size = abs(cur_x - prev_x) 
    i = i + 1 
    print("Iteratie",i,"\nValoarea lui x este",cur_x) 
    print("Minimul local se gaseste la:", cur_x)

cur_x = 3 
cur_y = 3
rate = 0.01 
precision = 0.000001 
previous_step_size = 1
previous_step_size1 = 1
max_iters = 10000 # max iter
i = 0 #iteration counter
df = lambda x: 2*x
df1 = lambda y: 4*y
while (previous_step_size > precision and previous_step_size1 > precision and i < max_iters):
    prev_x = cur_x 
    prev_y = cur_y
    cur_x = cur_x - rate * df(prev_x)
    cur_y = cur_y - rate * df1(prev_y)
    previous_step_size = abs(cur_x - prev_x) 
    previous_step_size1 = abs(cur_y - prev_y)
    i = i + 1
    print("Iteratia",i,"\nValoarea lui x este",cur_x, ",", cur_y) 
    print("Minimul local se gaseste:", cur_x, ",", cur_y)

cur_x = 3 
cur_y = 3
rate = 0.01 
precision = 0.000001 
previous_step_size = 1
previous_step_size1 = 1
max_iters = 10000 # max iter
i = 0 #iteration counter
while (previous_step_size > precision and previous_step_size1 > precision and i < max_iters):
    prev_x = cur_x 
    prev_y = cur_y
    df= C *( 202 * prev_x-202)
    df1= 400 * (prev_y * prev_y * prev_y - prev_x * prev_y) 
    cur_x = cur_x - rate * df(prev_x)
    cur_y = cur_y - rate * df1(prev_y)
    previous_step_size = abs(cur_x - prev_x) 
    previous_step_size1 = abs(cur_y - prev_y)
    i = i + 1
    print("Iteratie",i,"\nValoarea lui x este:",cur_x, ",", cur_y) 
    print("Minimul local se gaseste la:", cur_x, ",", cur_y)
# Out:
# Iteratie 1
# Valoarea lui x este 2.76
# Minimul local se gaseste 2.76
# Iteratie 2
# Valoarea lui x este 2.5488
# Minimul local se gaseste 2.5488
# Iteratie 3
# Valoarea lui x este 2.362944
# Minimul local se gaseste 2.362944
# Iteratie 4
# Valoarea lui x este 2.1993907200000002
# Minimul local se gaseste 2.1993907200000002
# Iteratie 5
# Valoarea lui x este 2.0554638336
# Minimul local se gaseste 2.0554638336
# Iteratie 6
# Valoarea lui x este 1.928808173568
# Minimul local se gaseste 1.928808173568
# Iteratie 7
# Valoarea lui x este 1.81735119273984
# Minimul local se gaseste 1.81735119273984
# Iteratie 8
# Valoarea lui x este 1.7192690496110592
# Minimul local se gaseste 1.7192690496110592
# Iteratie 9
# Valoarea lui x este 1.632956763657732
# Minimul local se gaseste 1.632956763657732
# Iteratie 10
# Valoarea lui x este 1.557001952018804
# Minimul local se gaseste 1.557001952018804
# Iteratie 11
# Valoarea lui x este 1.4901617177765476
# ...
